# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import serial
import time
import csv

# %%
# test dataframe visualization
#dataFrame_12 = pd.read_csv("sonar_data_12.csv") 
#dataFrame_18 = pd.read_csv("sonar_data_18.csv") 
#dataFrame_22 = pd.read_csv("sonar_data_22.csv")  
#dataFrame_29 = pd.read_csv("sonar_data_29.csv") 

dataFrame = pd.read_csv("data_24.csv") 

dataFrame['time'].
dataFrame.head(5)
# Out:
#    sonar_raw  sonar_mean  sonar_median  lidar_raw          time
# 0      26.95       26.95         26.95       24.2  1.606224e+09
# 1      26.95       26.95         26.95       23.7  1.606224e+09
# 2      26.95       26.95         26.95       23.6  1.606224e+09
# 3      26.95       26.95         26.95       23.9  1.606224e+09
# 4      26.95       26.95         26.95       23.8  1.606224e+09

# %%
# any missing values

dataFrame.isnull().values.any()
# Out:
# False

# %%
# how many any missing values
dataFrame.isnull().sum()
# Out:
# sonar_raw       0
# sonar_mean      0
# sonar_median    0
# lidar_raw       0
# time            0
# dtype: int64

# %%
# size of rows
len(dataFrame)
# Out:
# 7073

# %%
# graph measures x time
plt.figure(figsize=(15,7))
ax = plt.gca()

dataFrame.plot(kind='line',x="time", y='sonar_raw', color = 'blue', ax=ax)
dataFrame.plot(kind='line',x="time", y='sonar_median', color = 'green', ax=ax)
dataFrame.plot(kind='line',x="time", y='sonar_mean', color = 'red', ax=ax)

#plt.xlabel('Time')
#plt.ylabel('Measures (cm)')
#plt.title('Measures x Time (Lixeira Cheia)')
plt.show()

# %%
# graph measures x time
plt.figure(figsize=(15,7))
ax = plt.gca()

#dataFrame.plot(kind='line',x="time", y='sonar_raw', color = 'blue', ax=ax)
dataFrame.plot(kind='line',x="time", y='lidar_raw', color = 'red',ax=ax)

#plt.xlabel('Time')
#plt.ylabel('Measures (cm)')
#plt.title('Measures x Time (Lixeira Cheia)')
plt.show()
